# %% [markdown]
# <a href="https://colab.research.google.com/github/nickhorowitz/nick/blob/main/simple_projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year!")
else:
    print(f"{year} is not a leap year.")
# Out:
# Enter a year: 300
# 300 is not a leap year.

# %%
import random

user_choice = input("Enter your choice (rock, paper, or scissors): ")
computer_choice = random.choice(["rock", "paper", "scissors"])

print(f"You chose: {user_choice}")
print(f"Computer chose: {computer_choice}")

if user_choice == computer_choice:
    print("It's a tie!")
elif (
    (user_choice == "rock" and computer_choice == "scissors") or
    (user_choice == "paper" and computer_choice == "rock") or
    (user_choice == "scissors" and computer_choice == "paper")
):
    print("You win!")
else:
    print("Computer wins!")
# Out:
# Enter your choice (rock, paper, or scissors): paper
# You chose: paper
# Computer chose: paper
# It's a tie!

# %%
# !pip install ColabTurtlePlus

# %%
# !pip install mplfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.5 MB/s eta 0:00:00
# ...

# %%
from ColabTurtlePlus.Turtle import *

clearscreen()
#setup(600,600)
#showborder()

# %%
reset = True

if reset:
  clear()

color("black", "green")
shape("blank")
begin_fill()
jumpto(0,0)
#color('blue')

forward(100)
left(90)
forward(100)
left(90)
forward(100)
left(90)
forward(100)
penup()
end_fill()

jumpto(-100,-100)
pendown()
color("blue")
begin_fill()
circle(50)
end_fill()

jumpto(100,-100)
pendown()
color("blue")
begin_fill()
circle(50)
end_fill()
# Out:
#       <svg width="600" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 400.0  L 300.0 300.0  L 500.0 300.0  L 500.0 200.0  L 300.0 200.0  L 300.0 300.0 " stroke-linecap="round" style="stroke:none;stroke-width:1" fill="green" /><path fill-rule="evenodd" fill-opacity="1" d="M 200.0 400.0  A 50 50 0 0 0 300.0 400.0  A 50 50 0 0 0 200.0 400.0 " stroke-linecap="round" style="stroke:blue;stroke-width:1" fill="blue" /><path fill-rule="evenodd" fill-opacity="1" d="M 400.0 400.0  A 50 50 0 0 0 500.0 400.0  A 50 50 0 0 0 400.0 400.0 " stroke-linecap="round" style="stroke:blue;stroke-width:1" fill="blue" />
#
#
#
#       </svg>

# %%
clearscreen()
n = int(input('Number of sides: '))

angles = 360 / n

if reset:
  clear()

color("red", "yellow")
shape("turtle")
begin_fill()

for i in range(n):
  forward(50)
  left(angles)

end_fill()
# Out:
# Number of sides: 5
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 450.0 300.0  L 465.451 252.447  L 425.0 223.058  L 384.549 252.447  L 400.0 300.0 " stroke-linecap="round" style="stroke:red;stroke-width:1" fill="yellow" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90.0,400.0,300.0) translate(400.0, 300.0)">
# ...

# %%
import math

if reset:
  clearscreen()

color("red", "yellow")
shape("blank")
begin_fill()

radius = int(input('Enter radius: '))

perimeter = 2 * math.pi * radius

angles = 10

steps = int(360 / angles)

distance = perimeter / steps

jumpto(0,0)

for i in range(steps):
  forward(5)
  left(angles)

end_fill()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 400.0 300.0  L 400.0 300.0  L 405.0 300.0  L 409.924 299.132  L 414.622 297.422  L 418.952 294.922  L 422.782 291.708  L 425.996 287.878  L 428.496 283.548  L 430.206 278.85  L 431.074 273.926  L 431.074 268.926  L 430.206 264.002  L 428.496 259.304  L 425.996 254.974  L 422.782 251.144  L 418.952 247.93  L 414.622 245.43  L 409.924 243.72  L 405.0 242.852  L 400.0 242.852  L 395.076 243.72  L 390.378 245.43  L 386.048 247.93  L 382.218 251.144  L 379.004 254.974  L 376.504 259.304  L 374.794 264.002  L 373.926 268.926  L 373.926 273.926  L 374.794 278.85  L 376.504 283.548  L 379.004 287.878  L 382.218 291.708  L 386.048 294.922  L 390.378 297.422  L 395.076 299.132  L 400.0 300.0 " stroke-linecap="round" style="stroke:red;stroke-width:1" fill="yellow" />
#
#
#
#       </svg>
# Enter radius: 10

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf
import seaborn as sns
import time

# Set Seaborn style
sns.set(style="whitegrid")


# Replace 'AAPL' with the desired stock symbol
stock_symbol = 'NVDA'
duration_minutes = 30

start_time = time.time()

# Download real-time stock data
# You can change the period and interval as needed
# Period options: '1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max'
# Interval options: '1m', '2m', '5m', '15m', '30m', '60m', '90m', '1h', '1d', '5d', '1wk', '1mo', '3mo'
stock_data = yf.download(stock_symbol, period='1d', interval='1m')

# Plotting with Seaborn
mpf.plot(stock_data, type='candle', style='yahoo', title=f'{stock_symbol} Stock Price',
              ylabel='Stock Price (USD)')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
# [*********************100%%**********************]  1 of 1 completed

# %%
# !pip install qrcode[pil]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import qrcode

def generate_qr_code(data, filename='qrcode.png'):
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=20,
        border=4,
    )
    qr.add_data(data)
    qr.make(fit=True)

    img = qr.make_image(fill_color="black", back_color="white")

    img.save(filename)
    print(f"QR code saved as '{filename}'")

if __name__ == "__main__":
    data_to_encode = input("Enter the data to encode in the QR code: ")
    generate_qr_code(data_to_encode)
# Out:
# Enter the data to encode in the QR code: https://erskordi.weebly.com/
# QR code saved as 'qrcode.png'

# %%
import pandas as pd

data = pd.read_json("https://data.cityofchicago.org/resource/m6dm-c72p.json?$query=SELECT%0A%20%20%60trip_id%60%2C%0A%20%20%60trip_start_timestamp%60%2C%0A%20%20%60trip_end_timestamp%60%2C%0A%20%20%60trip_seconds%60%2C%0A%20%20%60trip_miles%60%2C%0A%20%20%60pickup_census_tract%60%2C%0A%20%20%60dropoff_census_tract%60%2C%0A%20%20%60pickup_community_area%60%2C%0A%20%20%60dropoff_community_area%60%2C%0A%20%20%60fare%60%2C%0A%20%20%60tip%60%2C%0A%20%20%60additional_charges%60%2C%0A%20%20%60trip_total%60%2C%0A%20%20%60shared_trip_authorized%60%2C%0A%20%20%60trips_pooled%60%2C%0A%20%20%60pickup_centroid_latitude%60%2C%0A%20%20%60pickup_centroid_longitude%60%2C%0A%20%20%60pickup_centroid_location%60%2C%0A%20%20%60dropoff_centroid_latitude%60%2C%0A%20%20%60dropoff_centroid_longitude%60%2C%0A%20%20%60dropoff_centroid_location%60%0AWHERE%0A%20%20%60trip_start_timestamp%60%0A%20%20%20%20BETWEEN%20%222022-06-01T00%3A00%3A00%22%20%3A%3A%20floating_timestamp%0A%20%20%20%20AND%20%222022-06-30T23%3A45%3A00%22%20%3A%3A%20floating_timestamp")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     1000 non-null   object
#  1   trip_start_timestamp        1000 non-null   object
#  2   trip_end_timestamp          1000 non-null   object
#  3   trip_seconds                1000 non-null   int64
#  4   trip_miles                  1000 non-null   float64
#  5   pickup_census_tract         366 non-null    float64
#  6   pickup_community_area       954 non-null    float64
#  7   fare                        999 non-null    float64
#  8   tip                         999 non-null    float64
#  9   additional_charges          999 non-null    float64
#  10  trip_total                  999 non-null    float64
#  11  shared_trip_authorized      1000 non-null   bool
#  12  trips_pooled                1000 non-null   int64
# ...

# %%
data.corr()
# Out:
# <ipython-input-13-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                             trip_seconds  trip_miles  pickup_census_tract  \
# trip_seconds                    1.000000    0.896409             0.314794
# trip_miles                      0.896409    1.000000             0.328369
# pickup_census_tract             0.314794    0.328369             1.000000
# pickup_community_area           0.260147    0.307068             0.763255
# fare                            0.764787    0.841906             0.434863
# tip                             0.353622    0.459438             0.187158
# additional_charges              0.589127    0.645184             0.504603
# trip_total                      0.761151    0.847386             0.447814
# ...

# %%
data.plot(kind='scatter',x='trip_seconds',y='pickup_community_area')
# Out:
# <Axes: xlabel='trip_seconds', ylabel='pickup_community_area'>

# %%
import instaloader

def fetch_user_info(username):
    L = instaloader.Instaloader()
    try:
        profile = instaloader.Profile.from_username(L.context, username)
        print(f"Username: {profile.username}")
        print(f"Full Name: {profile.full_name}")
        print(f"Followers: {profile.followers}")
        print(f"Posts: {profile.mediacount}")
        print(f"Biography: {profile.biography}")
        print("\nRecent Posts:")
        for post in profile.get_posts():
            print(post.url)
    except instaloader.exceptions.ProfileNotExistsException:
        print(f"User '{username}' not found.")

if __name__ == "__main__":
    username = input("Enter Instagram username: ")
    fetch_user_info(username)
